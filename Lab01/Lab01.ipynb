# %% [markdown]
# # Task 1

# %%
import numpy as np
import pandas as pd

# %%
## import dataset

dataset = pd.read_csv('online_store_customer_data.csv')

# %%
dataset
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
## Create a random 4x4 array from an exponential distribution
random_array = np.random.exponential(size=(4, 4))

# %%
random_array
# Out:
# array([[0.31988418, 1.5746032 , 2.68308061, 1.72471507],
#        [0.58877647, 0.33604975, 1.92091865, 0.67969347],
#        [0.8717249 , 0.49699522, 4.29176294, 0.01879393],
#        [0.05177624, 6.26379855, 0.61316185, 0.8067327 ]])

# %%
## Create a random 100000x1 array 
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="rand")
# Out:
# (array([0.97900803, 0.97100796, 1.02200838, 0.976008  , 1.02800843,
#         0.99800818, 0.99800818, 1.05200863, 0.97300798, 0.99800818,
#         1.03500849, 1.04300855, 1.03200846, 0.95000779, 1.04700858,
#         1.02700842, 1.00800826, 0.92200756, 0.94500775, 1.02900844,
#         0.99000812, 0.96900794, 1.04400856, 0.95500783, 0.99400815,
#         0.95400782, 1.10900909, 0.99500816, 0.98600808, 0.95400782,
#         0.98000803, 1.04500857, 1.04200854, 0.97200797, 1.02000836,
#         1.00300822, 1.00700826, 0.93300765, 0.96100788, 1.02900844,
#         0.97500799, 0.97300798, 0.99200813, 0.99900819, 1.00100821,
#         1.01100829, 1.06000869, 1.0250084 , 1.02600841, 1.00300822,
#         0.99000812, 1.01400831, 0.9510078 , 1.07600882, 1.00400823,
#         1.01100829, 1.01800835, 1.00900827, 1.01100829, 1.01900835,
#         1.00100821, 0.99000812, 0.98200805, 0.96600792, 0.94200772,
#         0.94900778, 1.00500824, 0.98700809, 0.99700817, 0.94100772,
# ...

# %%
plt.axis([-2.5, 2.5, 0, 1.1])
# Out:
# (-2.5, 2.5, 0.0, 1.1)

# %%
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# %%
# Calculate
Z = X**2 + Y**2

# %%
# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap="viridis")
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
plt.title("3D Plot")
# Out:
# Text(0.5, 0.92, '3D Plot')

# %%
plt.show()

# %%
## Calculate the pearson standard 

import seaborn as sns

# %%
# Select columns
selected_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
correlation_matrix = df[selected_columns].corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Select columns
#       2 selected_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
# ----> 3 correlation_matrix = df[selected_columns].corr()
#
# NameError: name 'df' is not defined

# %%
# Calculate correlations
pearson_corr = correlation_matrix.corr(method='pearson')
spearman_corr = correlation_matrix.corr(method='spearman')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Calculate correlations
# ----> 2 pearson_corr = correlation_matrix.corr(method='pearson')
#       3 spearman_corr = correlation_matrix.corr(method='spearman')
#
# NameError: name 'correlation_matrix' is not defined

# %%
# Visualize Pearson correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Pearson Correlation Coefficient')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Visualize Pearson correlation heatmap
#       2 plt.figure(figsize=(8, 6))
# ----> 3 sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', center=0)
#       4 plt.title('Pearson Correlation Coefficient')
#       5 plt.show()
#
# NameError: name 'pearson_corr' is not defined

# %%
# Pandas for managing datasets
import pandas as pd

# %%
# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline
# Seaborn for plotting and styling
import seaborn as sns

# %%
# Read dataset
df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
# Select relevant columns
selected_columns = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']

# %%
# Calculate correlations
correlation_matrix = df[selected_columns].corr()

# %%
pearson_corr = correlation_matrix.corr(method='pearson')
spearman_corr = correlation_matrix.corr(method='spearman')

# %%
# Pearson correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Pearson Correlation Coefficient')
plt.show()

# %%
# Spearman correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', center=0)
plt.title('Spearman Rank Correlation')
plt.show()

# %% [markdown]
# # Task 2

# %%
dataset2 = pd.read_csv('Au_nanoParticle_dataset.csv')

# %%
print(dataset2.head(20))
# Out:
#     ID    T       tau  time  N_total  N_bulk  N_surface        Volume  \
# 0    1  273  0.000025     1     1599    1014        585  2.710000e-26
# 1    2  273  0.000025     2     1642    1034        608  2.780000e-26
# 2    3  273  0.000025     3     4637    3365       1272  7.850000e-26
# 3    4  273  0.000025     4     7189    5292       1897  1.220000e-25
# 4    5  273  0.000025     5    11004    8508       2496  1.860000e-25
# 5    6  273  0.000025     6    13375   10768       2607  2.260000e-25
# 6    7  273  0.000025     7    13795   11155       2640  2.340000e-25
# 7    8  273  0.000025     8    13947   11304       2643  2.360000e-25
# 8    9  273  0.000025     9    14020   11357       2663  2.370000e-25
# 9   10  273  0.000025    10    14056   11389       2667  2.380000e-25
# 10  11  273  0.000050     1     1534     966        568  2.600000e-26
# 11  12  273  0.000050     2     1559     974        585  2.640000e-26
# ...

# %%
# Filter columns [N_total, N_bulk, N_surface, R_avg]
filtered_dataset2 = dataset2[['N_total', 'N_bulk', 'N_surface', 'R_avg']]

# %%
# Display the first 20 samples of the new DataFrame
print(filtered_dataset2.head(20))
# Out:
#     N_total  N_bulk  N_surface    R_avg
# 0      1599    1014        585  17.3706
# 1      1642    1034        608  17.6061
# 2      4637    3365       1272  25.3692
# 3      7189    5292       1897  29.7011
# 4     11004    8508       2496  34.2831
# 5     13375   10768       2607  36.6334
# 6     13795   11155       2640  37.0108
# 7     13947   11304       2643  37.1672
# 8     14020   11357       2663  37.2103
# 9     14056   11389       2667  37.2467
# 10     1534     966        568  17.1107
# 11     1559     974        585  17.2101
# 12     4356    3099       1257  24.8253
# 13     6550    4675       1875  29.0376
# 14    10175    7748       2427  33.4399
# 15    12393    9842       2551  35.6950
# 16    13207   10590       2617  36.4657
# 17    13543   10937       2606  36.7871
# 18    13713   11079       2634  36.9333
# 19    13791   11151       2640  37.0104

# %%
# Calculate mean, standard deviation, and quartile values for each column
statistics = filtered_dataset2.describe()
print(statistics)
# Out:
#             N_total        N_bulk   N_surface        R_avg
# count   4000.000000   4000.000000  4000.00000  4000.000000
# mean    3476.786500   2521.550250   955.23625    20.654363
# std     3679.286769   2976.232459   721.87022     7.610716
# min      236.000000     89.000000   137.00000     8.528600
# 25%     1061.000000    618.750000   437.00000    15.160725
# 50%     1867.000000   1199.000000   666.00000    18.629250
# 75%     4503.000000   3183.000000  1301.75000    25.525125
# max    14277.000000  11580.000000  3190.00000    39.239200

# %%
# Plot histograms of the features in a 1x4 layout
plt.figure(figsize=(15, 4))

for i, column in enumerate(filtered_dataset2.columns):
    plt.subplot(1, 4, i + 1)
    plt.hist(filtered_dataset2[column], bins=20, color='skyblue', edgecolor='black')
    plt.title(column)
    plt.xlabel('Value')
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Visualize scatter plots and histograms
sns.pairplot(filtered_dataset2)
plt.show()

# %%
# Create a PairGrid with modified diagonal and lower plots
g = sns.PairGrid(filtered_dataset2)

# Bivariate histogram

g.map_upper(sns.histplot)

 # Histogram with KDE on diagonal
    
g.map_diag(sns.histplot, kde=True) 

 # Bivariate KDE
    
g.map_lower(sns.kdeplot)  

plt.show()
